# %%
import argparse
import io
from google.cloud import speech
from google.cloud.speech import enums
from google.cloud.speech import types
import json

# %%
def transcribe_gcs(gcs_uri):
    """Asynchronously transcribes the audio file specified by the gcs_uri."""
    from google.cloud import speech

    client = speech.SpeechClient()

    audio = types.RecognitionAudio(uri=gcs_uri)
    config = types.RecognitionConfig(
        encoding=types.RecognitionConfig.AudioEncoding.FLAC,
        sample_rate_hertz=48000,
        language_code="en-US",
        audio_channel_count=2,
        enable_automatic_punctuation=True,
    )

    operation = client.long_running_recognize(config=config, audio=audio)

    print("Waiting for operation to complete...")
    response = operation.result(timeout=2000)
    
    # Each result is for a consecutive portion of the audio. Iterate through
    # them to get the transcripts for the entire audio file.
    #for result in response.results:
        # The first alternative is the most likely one for this portion.
        #print(u"Transcript: {}".format(result.alternatives[0].transcript))
        #print("Confidence: {}".format(result.alternatives[0].confidence))
    print(response)

# %%
transcribe_gcs("gs://meeting-audio-team13/test_rec.flac")
# Out:
# Waiting for operation to complete...
# results {
#   alternatives {
#     transcript: "What is an example of an online meeting with two teams wants to discuss a new project to build a Convention Center on a piece of land owned by municipality."
#     confidence: 0.9409086108207703
#   }
# }
# results {
#   alternatives {
#     transcript: " The members of team number one the real estate developer or Alexander in Brazil connected with a PC dumb in Indian connected with a Mac and met in the United States connected with a Mac. The members of team number to the municipality are Christina in the United States with a PC. He ran in India with a PC Rancho in the United States with a PC and Vicky in France with an iPhone and I am the ghost with that meeting. I am in the United States and I\'m connected with a Mac first. I\'m going to have a private meeting with a team leader of the municipality for participating in our online meeting."
#     confidence: 0.9628276228904724
#   }
# }
# results {
#   alternatives {
#     transcript: " You represent the theme of the municipality by so you own the piece of land where there is an abandoned airport now secretary."
#     confidence: 0.8873001337051392
#   }
# }
# results {
#   alternatives {
#     transcript: " Okay. Now I want just wanted to double-check with you that you and your team are ready to discuss this project today. You\'re ready. Okay. So let let me bring Alexander in okay."
#     confidence: 0.9105910658836365
#   }
# }
# results {
#   alternatives {
#     transcript: " Alexander Alexander, you are the team leader of the real estate developer. Is that correct? And you already know Christina because you\'re making the best."
#     confidence: 0.8986202478408813
#   }
# }
# results {
#   alternatives {
#     transcript: " Hi Christina, how are you?"
#     confidence: 0.9501129388809204
#   }
# }
# results {
#   alternatives {
#     transcript: " Okay, Alexander. I wanted to check with you that your team is ready to discuss our project today. You\'re ready. Okay. So what I\'m going to do, I\'m going to bring everybody back. Okay, so now they\'re on hold."
#     confidence: 0.9289572238922119
#   }
# }
# results {
#   alternatives {
#     transcript: " And then we\'ll take it from there Alexandra if you want you can mute yourself."
#     confidence: 0.9366430640220642
#   }
# }
# results {
#   alternatives {
#     transcript: " Okay. Thank you. Alright, so let me bring everybody back."
#     confidence: 0.9391294717788696
#   }
# }
# results {
#   alternatives {
#     transcript: " Okay, so welcome everybody and you know that each of you belongs to a different team. So Christina Aranda Rancho and beachy are part of the team of the municipality is owns a piece of land and Alexander told me Max."
#     confidence: 0.9009087681770325
#   }
# }
# results {
#   alternatives {
#     transcript: " Are part of the team or the real estate developer who would like to build something on on that piece of land? Okay now just to make sure that we are on the same page. I\'m going to share with you."
#     confidence: 0.9355201721191406
#   }
# }
# results {
#   alternatives {
#     transcript: " A video showing in abandoned airport. Okay, so give me"
#     confidence: 0.9252470135688782
#   }
# }
# results {
#   alternatives {
#     transcript: " seconds"
#     confidence: 0.8226171135902405
#   }
# }
# results {
#   alternatives {
#     transcript: " So this is the airport that we\'re talking about that is somewhere in the world. And as you can see is not in a great shape and this piece of land is owned by the municipality that today is represented by Christina\'s in okay."
#     confidence: 0.934650182723999
#   }
# }
# results {
#   alternatives {
#     transcript: " As you can see there is a lot of work to be done."
#     confidence: 0.8869098424911499
#   }
# }
# results {
#   alternatives {
#     transcript: " So let\'s stop this."
#     confidence: 0.984129786491394
#   }
# }
# results {
#   alternatives {
#     transcript: " Okay, and let me show you something else."
#     confidence: 0.9758910536766052
#   }
# }
# results {
#   alternatives {
#     transcript: " Let me show you."
#     confidence: 0.9857326149940491
#   }
# }
# results {
#   alternatives {
#     transcript: " then"
#     confidence: 0.8486727476119995
#   }
# }
# results {
#   alternatives {
#     transcript: " the design of a Convention Center"
#     confidence: 0.9053716063499451
#   }
# }
# results {
#   alternatives {
#     transcript: " Let\'s Alexander."
#     confidence: 0.5648711919784546
#   }
# }
# results {
#   alternatives {
#     transcript: " Alexander theme would like to build okay. So ERS, do you all see it is that there\'s a image on your screen?"
#     confidence: 0.8600694537162781
#   }
# }
# results {
#   alternatives {
#     transcript: " Okay, is it as you can see is a is a pretty new modern convention center with a lot of space Also for a will taking a nap like this people here, right? Okay. So let me get this. Let me stop this. Okay. So now that we know which projects with talking about."
#     confidence: 0.9344260096549988
#   }
# }
# results {
#   alternatives {
#     transcript: " I think it would be useful if I give you a gift exchange opportunity to brainstorm some ideas. Ask some funnel questions Sun going to create two separate rooms for each team. And then I\'m going to join each team ask you if you have any final questions. Hopefully you will not have any questions and then I\'ll bring y\'all back together and then we will decide what is going to happen next. Okay, so let me create some breakout rooms."
#     confidence: 0.9624576568603516
#   }
# }
# results {
#   alternatives {
#     transcript: " with"
#     confidence: 0.8459653854370117
#   }
# }
# results {
#   alternatives {
#     transcript: " Alexander match"
#     confidence: 0.7258943319320679
#   }
# }
# results {
#   alternatives {
#     transcript: " Tom"
#     confidence: 0.6876237392425537
#   }
# }
# results {
#   alternatives {
#     transcript: " and then we ran Christina Rachel and Vicki, okay."
#     confidence: 0.7987626791000366
#   }
# }
# results {
#   alternatives {
#     transcript: " Well, I have a good news. It seems that both your teams are ready and we\'ll go ahead with it. Okay. So what I suggest is that the next step is going to be a meeting in London in March at the Savoy Hotel finalize project. Christina also said that the awesome man."
#     confidence: 0.9487706422805786
#   }
# }
# results {
#   alternatives {
#     transcript: " The details that she would like to discuss Alexander and that\'s certainly can be alright, okay, so let me know if it\'s okay with you. I\'m going to run up to whatever you want, whatever you have a great. So let me"
#     confidence: 0.9202873706817627
#   }
# }
# results {
#   alternatives {
#     transcript: " Okay, hold up."
#     confidence: 0.5298423767089844
#   }
# }
# results {
#   alternatives {
#     transcript: " It documents. Okay, and the document is going to be very easy in agreement."
#     confidence: 0.9517885446548462
#   }
# }
# results {
#   alternatives {
#     transcript: " and agreements regarding this"
#     confidence: 0.7367016077041626
#   }
# }
# results {
#   alternatives {
#     transcript: " convention"
#     confidence: 0.8733565807342529
#   }
# }
# results {
#   alternatives {
#     transcript: " Center"
#     confidence: 0.8466367721557617
#   }
# }
# results {
#   alternatives {
#     transcript: " project"
#     confidence: 0.8706820607185364
#   }
# }
# results {
#   alternatives {
#     transcript: " As you can see it\'s very safe for agreements, but that is what you have a great and a Christina."
#     confidence: 0.9217635989189148
#   }
# }
# results {
#   alternatives {
#     transcript: " Christina and Alexander"
#     confidence: 0.9114940762519836
#   }
# }
# results {
#   alternatives {
#     transcript: " will discuss"
#     confidence: 0.7036620378494263
#   }
# }
# results {
#   alternatives {
#     transcript: " It resolved."
#     confidence: 0.7518254518508911
#   }
# }
# results {
#   alternatives {
#     transcript: " Any final issues?"
#     confidence: 0.9480285048484802
#   }
# }
# results {
#   alternatives {
#     transcript: " before"
#     confidence: 1.0
#   }
# }
# results {
#   alternatives {
#     transcript: " the above meaning"
#     confidence: 0.865455150604248
#   }
# }
# results {
#   alternatives {
#     transcript: " are you okay with this?"
#     confidence: 0.9387930631637573
#   }
# }
# results {
#   alternatives {
#     transcript: " Okay, so I\'m going to to convert this document into a PDF file and I\'m going to send it to you by email. Okay? Alright, I think we\'ll done and thank you very much. So we\'ll see you all next month in London."
#     confidence: 0.9355593919754028
#   }
# }
